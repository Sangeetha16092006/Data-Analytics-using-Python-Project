# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangeetha16092006/Data-Analytics-using-Python-Project/blob/main/Practical_Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
  print("Hi Internship Students")
greet()
# Out:
# Hi Internship Students

# %%
def greet(name):
  print("Welcome",name)
greet("Keerthi")
# Out:
# Welcome Keerthi

# %%
def add(a,b):
  return a+b
result=add(10,20)
print(result)
# Out:
# 30
