# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangeetha16092006/Data-Analytics-using-Python-Project/blob/main/Practical_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Mark1=int(input("Enter Mark 1:"))
Mark2=int(input("Enter Mark 2:"))
Mark3=int(input("Enter Mark 3:"))

Total=Mark1+Mark2+Mark3
Average=Total/3

print("Total:",Total)
print("Average:",Average)

if Average>=50:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter Mark 1:70
# Enter Mark 2:80
# Enter Mark 3:60
# Total: 210
# Average: 70.0
# Pass
