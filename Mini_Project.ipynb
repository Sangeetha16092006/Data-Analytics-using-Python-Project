# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangeetha16092006/Data-Analytics-using-Python-Project/blob/main/Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **E-Commerce Sales Analysis**

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

uploaded =files.upload()

df=pd.read_csv("sales_data.csv")

print(df)
# Out:
#      <input type="file" id="files-3dca0b8c-7426-4724-845f-54a94ea6ba12" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3dca0b8c-7426-4724-845f-54a94ea6ba12">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head(20)
# Out:
#     Index                                            Name  \
# 0       1            Compact Printer Air Advanced Digital
# 1       2                                          Tablet
# 2       3                            Smart Blender Cooker
# 3       4                    Advanced Router Rechargeable
# 4       5                    Portable Mouse Monitor Phone
# 5       6                                           Radio
# 6       7  Ultra Projector Oven Thermostat Prime Advanced
# 7       8                              Webcam Stove Grill
# 8       9                                       Eco Radio
# 9      10               Ultra Powerbank Brush Charger Max
# 10     11                                   Wireless Dock
# 11     12                    Fast Camera Router Fan Smart
# 12     13                                    Heater Radio
# 13     14                     Smart Trimmer Webcam Heater
# 14     15                              Webcam Dock Heater
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Index         100 non-null    int64
#  1   Name          100 non-null    object
#  2   Description   100 non-null    object
#  3   Brand         100 non-null    object
#  4   Category      100 non-null    object
#  5   Price         100 non-null    int64
#  6   Currency      100 non-null    object
#  7   Stock         100 non-null    int64
#  8   EAN           100 non-null    int64
#  9   Color         100 non-null    object
#  10  Size          100 non-null    object
#  11  Availability  100 non-null    object
#  12  Internal ID   100 non-null    int64
# dtypes: int64(5), object(8)
# memory usage: 10.3+ KB
# None

# %%
print(df.shape)
# Out:
# (100, 13)

# %%
print(df.isnull().sum())
# Out:
# Index           0
# Name            0
# Description     0
# Brand           0
# Category        0
# Price           0
# Currency        0
# Stock           0
# EAN             0
# Color           0
# Size            0
# Availability    0
# Internal ID     0
# dtype: int64

# %%
df=df.drop_duplicates()
print(df)
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ...

# %%
total_sales=(df["Price"]*df["Stock"]).sum()
print("Total Sales:",total_sales)
# Out:
# Total Sales: 24452583

# %%
Category_Sales=df.groupby("Category")["Price"].sum()
print(Category_Sales)
# Out:
# Category
# Accessories (Bags, Hats, Belts)     206
# Automotive                         2530
# Beauty & Personal Care             1114
# Bedding & Bath                     1812
# Books & Stationery                 1554
# Cameras & Accessories               889
# Camping & Hiking                   1838
# Cleaning Supplies                  2348
# Clothing & Apparel                  858
# Cycling                            2398
# Fishing & Hunting                   100
# Fitness Equipment                  2110
# Fragrances                         1910
# Furniture                          1378
# Grooming Tools                     1405
# Haircare                           2045
# Health & Wellness                  1610
# Home & Kitchen                      735
# Home Decor                         1565
# Kids' Clothing                     1989
# Kitchen Appliances                  753
# Laptops & Computers                 984
# Makeup                              515
# ...

# %%
Category_Sales.plot(kind='bar')
plt.title("Category Sales Analysis")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.show()
